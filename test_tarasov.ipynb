# %%
gaussian := Exp[ -(p-p0)^2/(2 sigma^2)];
tarasov = Integrate[Exp[-(x+p-p0)^2/(2 sigma^2)] Exp[-x/tau],{x,0,Infinity},Assumptions->{sigma>0,tau>0,p0>0}]
tarasov0 = tarasov/.{p->p0};
tarasovN = Simplify[tarasov/tarasov0] (* Normalize at the peak position.*)
# Out:
#        2                             2                           2
#  (sigma  + 2 p tau - 2 p0 tau)/(2 tau )      Pi             sigma  + (p - p0) tau
# E                                       Sqrt[--] sigma Erfc[---------------------]
#                                              2                Sqrt[2] sigma tau
#                         2
#  (p - p0)/tau      sigma  + (p - p0) tau
# E             Erfc[---------------------]
#                      Sqrt[2] sigma tau
# -----------------------------------------
#                     sigma
#             Erfc[-----------]
#                  Sqrt[2] tau

# %%
LogPlot[{gaussian,tarasovN}/.{p0->40,tau->1,sigma->1},{p,30,50}] (* Both function meet at p0 *)
# Out:
# -Graphics-

# %%
Plot[{gaussian,tarasovN}/.{p0->40,tau->1,sigma->1},{p,30,50},PlotRange->{0.01,2}] (* Both function meet at p0 *)
# Out:
# -Graphics-

# %%
Integrate[Exp[-(x+p-p0)^2/(2 sigma^2)] Exp[-(x+40)/tau],{x,0,Infinity},Assumptions->{sigma>0,tau>0,p0>0}]
LogPlot[%/.{p0->40,tau->1,sigma->1},{p,30,50}] (* Both function meet at p0 *)
# Out:
#        2                              2                           2
#  (sigma  + 2 (40 + p - p0) tau)/(2 tau )      Pi             sigma  + (p - p0) tau
# E                                        Sqrt[--] sigma Erfc[---------------------]
#                                               2                Sqrt[2] sigma tau
# -Graphics-

# %%
Integrate[Exp[-(x+p-p0)^2/(2 sigma^2)] Exp[-(x+40)/tau],{x,0,Infinity},Assumptions->{sigma>0,tau>0,p0>0}]
LogPlot[%/.{p0->40,tau->1,sigma->1},{p,30,50}] (* Both function meet at p0 *)
# Out:
#        2                               2                           2
#  (sigma  + 2 (-40 + p - p0) tau)/(2 tau )      Pi             sigma  + (p - p0) tau
# E                                         Sqrt[--] sigma Erfc[---------------------]
#                                                2                Sqrt[2] sigma tau
# -Graphics-
