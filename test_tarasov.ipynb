# %%
psi = Integrate[Exp[-(p-p0-x)^2/(2 sigma^2)] Exp[-x/tau],{x,0,Infinity},Assumptions->{sigma>0,tau>0,p0>0}]
# Out:
#        2                             2                           2
#  (sigma  - 2 p tau + 2 p0 tau)/(2 tau )      Pi             sigma  + (-p + p0) tau
# E                                       Sqrt[--] sigma Erfc[----------------------]
#                                              2                Sqrt[2] sigma tau

# %%
fp = Exp[p/tau] (1-Erf[(p-p0+sigma^2/tau-shift tau)/Sqrt[2]/sigma])
LogPlot[fp/.{tau->1,p0->40,sigma->1,shift->0},{p,0,60}]
# Out:
#                               2
#                          sigma
#                 p - p0 + ------ - shift tau
#  p/tau                    tau
# E      (1 - Erf[---------------------------])
#                        Sqrt[2] sigma
# -Graphics-

# %%
Plot[fp/.{tau->1,p0->40,sigma->1,shift->0},{p,35,45}]
# Out:
# -Graphics-

# %%
gaussian := Exp[ -(p-p0)^2/(2 sigma^2)];
tarasov = Integrate[Exp[-(x+p-p0)^2/(2 sigma^2)] Exp[-x/tau],{x,0,Infinity},Assumptions->{sigma>0,tau>0,p0>0}]
tarasov0 = tarasov/.{p->p0};
tarasovN = Simplify[tarasov/tarasov0];
# Out:
#        2                             2                           2
#  (sigma  + 2 p tau - 2 p0 tau)/(2 tau )      Pi             sigma  + (p - p0) tau
# E                                       Sqrt[--] sigma Erfc[---------------------]
#                                              2                Sqrt[2] sigma tau

# %%
LogPlot[{gaussian,tarasovN}/.{p0->40,tau->1,sigma->1},{p,30,50}] (* Both function meet at p0 *)
# Out:
# -Graphics-

# %%
Plot[{gaussian,tarasovN}/.{p0->40,tau->1,sigma->1},{p,30,50},PlotRange->{0.01,2}] (* Both function meet at p0 *)
# Out:
# -Graphics-
